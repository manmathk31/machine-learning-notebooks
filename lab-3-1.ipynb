# %% [markdown]
# Version: 02.14.2023

# %% [markdown]
# # Lab 3.1: Extracting Text from Webpages and Images
#
# In this lab, you will use Beautiful Soup and Amazon Textract to extract text from the web and turn the results into a pandas dataframe.
#
# In the second part of the lab, you will experiment with Amazon Textract to extract text from images.
#
#
# ## Lab steps
#
# To complete this lab, you will follow these steps:
#
# 1. [Extracting information from a webpage](#1.-Extracting-information-from-a-webpage)
# 2. [Extracting text from images](#2.-Extracting-text-from-images)

# %%
#Upgrade dependencies
# !pip install --upgrade pip
# !pip install --upgrade sagemaker
# !pip install --upgrade beautifulsoup4
# !pip install --upgrade html5lib
# !pip install --upgrade requests
# !pip install --upgrade textract-trp
# Out:
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (26.2)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.9 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.2
#     Uninstalling pip-26.2:
#       Successfully uninstalled pip-26.2
# Successfully installed pip-26.2.1
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.257.6)
# Collecting sagemaker
#   Downloading sagemaker-3.20.0-py3-none-any.whl.metadata (20 kB)
# Collecting sagemaker-core<3.0.0,>=2.20.0 (from sagemaker)
#   Downloading sagemaker_core-2.20.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting sagemaker-train<2.0.0,>=1.20.0 (from sagemaker)
#   Downloading sagemaker_train-1.20.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting sagemaker-serve<2.0.0,>=1.20.0 (from sagemaker)
#   Downloading sagemaker_serve-1.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting sagemaker-mlops<2.0.0,>=1.20.0 (from sagemaker)
#   Downloading sagemaker_mlops-1.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: boto3<2.0.0,>=1.43.20 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (1.43.68)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.13.4)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (6.0.3)
# Requirement already satisfied: jsonschema<5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.26.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.11.0)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (14.3.4)
# Requirement already satisfied: mock<5.0,>4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.0.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (6.11.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.16.0)
# Requirement already satisfied: pytz>=2021.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2026.3.post1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.34.2)
# Requirement already satisfied: attrs>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (25.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (24.2)
# Requirement already satisfied: protobuf<7.0.0,>=3.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (6.33.6)
# Requirement already satisfied: pandas>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.3.3)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.2.6)
# Requirement already satisfied: smdebug_rulesconfig>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (1.0.1)
# Requirement already satisfied: schema>=0.7.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.7.8)
# Requirement already satisfied: omegaconf>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.3.1)
# Collecting scipy>=1.5.0 (from sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: cloudpickle>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (3.1.2)
# Collecting paramiko>=2.11.0 (from sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached paramiko-5.0.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: tblib>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<3.0.0,>=2.20.0->sagemaker) (3.2.2)
# Collecting cryptography>=46.0.0 (from sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Downloading cryptography-50.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: botocore<1.44.0,>=1.43.68 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (1.43.68)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.68->boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.44.0,>=1.43.68->boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.7.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.4.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.68->boto3<2.0.0,>=1.43.20->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2.20.0)
# Collecting pyiceberg>=0.8.0 (from pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached pyiceberg-0.11.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Collecting pyarrow>=14.0.0 (from sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: s3fs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-mlops<2.0.0,>=1.20.0->sagemaker) (0.4.2)
# Collecting deepdiff (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached deepdiff-9.1.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting mlflow (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached mlflow-3.15.1-py3-none-any.whl.metadata (49 kB)
# Collecting sagemaker_schema_inference_artifacts (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached sagemaker_schema_inference_artifacts-0.0.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting pytest (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached pytest-9.1.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (4.70.0)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (7.2.2)
# Collecting tritonclient[http] (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached tritonclient-2.71.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting onnx (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached onnx-1.22.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxruntime (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached onnxruntime-1.23.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting torch>=2.0.0 (from sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached torch-2.13.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (38 kB)
# Requirement already satisfied: graphene<4,>=3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-train<2.0.0,>=1.20.0->sagemaker) (3.4.3)
# Collecting jinja2<4.0,>=3.0 (from sagemaker-train<2.0.0,>=1.20.0->sagemaker)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting sagemaker-mlflow<1.0.0,>=0.0.1 (from sagemaker-train<2.0.0,>=1.20.0->sagemaker)
#   Using cached sagemaker_mlflow-0.5.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting nest_asyncio>=1.5.0 (from sagemaker-train<2.0.0,>=1.20.0->sagemaker)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.20.0->sagemaker) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.20.0->sagemaker) (3.2.0)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0,>=3.0->sagemaker-train<2.0.0,>=1.20.0->sagemaker)
#   Using cached markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting mlflow-skinny==3.15.1 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached mlflow_skinny-3.15.1-py3-none-any.whl.metadata (50 kB)
# Collecting mlflow-tracing==3.15.1 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached mlflow_tracing-3.15.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached flask_cors-6.0.5-py3-none-any.whl.metadata (5.4 kB)
# Collecting Flask<4 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting aiohttp<4,>=3.7.0 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached aiohttp-3.14.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached alembic-1.19.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting cryptography>=46.0.0 (from sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached cryptography-49.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (7.2.0)
# Collecting gunicorn<27 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading gunicorn-26.1.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting huey<4,>=2.5.4 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached huey-3.3.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting matplotlib<4 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting scikit-learn<2 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting skops<1 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading sqlalchemy-2.0.52-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting cachetools<8,>=5.0.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cachetools-7.1.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (8.4.2)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading databricks_sdk-0.133.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: fastapi<1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.141.1)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached gitpython-3.1.59-py3-none-any.whl.metadata (13 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading sqlparse-0.6.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: starlette<2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (1.6.0)
# Requirement already satisfied: uvicorn<1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.52.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached propcache-0.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4,>=3.7.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached yarl-1.24.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (103 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached mako-1.4.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting tomli (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached tomli-2.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting cffi>=2.0.0 (from cryptography>=46.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached cffi-2.1.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached google_auth-2.56.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.0.5)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached fonttools-4.63.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.1 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached pillow-12.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (2026.3)
# Collecting joblib>=1.2.0 (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: prettytable>=3.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from skops<1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (3.18.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached greenlet-3.5.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from starlette<2->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (4.14.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<2->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.16.0)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=46.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker) (4.9.3)
# Collecting bcrypt>=3.2 (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting invoke>=2.0 (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached invoke-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting pynacl>=1.5 (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.20.0->sagemaker)
#   Using cached pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: wcwidth>=0.3.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from prettytable>=3.9->skops<1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.8.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (0.6.4)
# Collecting mmh3<6.0.0,>=4.0.0 (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached mmh3-5.2.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (14 kB)
# Collecting strictyaml<2.0.0,>=1.7.0 (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker) (2026.7.0)
# Collecting tenacity<10.0.0,>=8.2.3 (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting pyroaring<2.0.0,>=1.0.0 (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached pyroaring-1.1.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting cachetools<8,>=5.0.0 (from mlflow-skinny==3.15.1->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Collecting zstandard<1.0.0,>=0.13.0 (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.20.0->sagemaker)
#   Using cached zstandard-0.25.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Collecting filelock (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading filelock-3.32.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=77.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker) (83.0.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting cuda-toolkit==13.0.3 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cuda_toolkit-13.0.3.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cuda_bindings-13.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting nvidia-cudnn-cu13==9.20.0.48 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.1 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.29.7 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.7.1 (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached triton-3.7.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink<14,>=13.0.88 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_nvjitlink-13.3.33-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas==13.1.1.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting cuda-pathfinder>=1.4.2 (from cuda-bindings<14,>=13.0.3->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading cuda_pathfinder-1.6.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting cachebox<6,>=5.2 (from deepdiff->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached cachebox-5.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting orderly-set<6,>=5.5.0 (from deepdiff->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting ml_dtypes>=0.5.4 (from onnx->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading ml_dtypes-0.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting coloredlogs (from onnxruntime->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting iniconfig>=1.0.1 (from pytest->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pluggy<2,>=1.5 (from pytest->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting json5>=0.9.22 (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Collecting ml_dtypes>=0.5.4 (from onnx->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached ml_dtypes-0.5.4-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting python-rapidjson>=0.9.1 (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached python_rapidjson-1.23-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (24 kB)
# Collecting geventhttpclient>=2.3.3 (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached geventhttpclient-2.3.9-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached greenlet-3.3.2-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting gevent (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached gevent-26.8.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting brotli (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting zope.event (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Using cached zope_event-6.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting zope.interface (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.20.0->sagemaker)
#   Downloading zope_interface-8.6-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (47 kB)
# Downloading sagemaker-3.20.0-py3-none-any.whl (11 kB)
# Downloading sagemaker_core-2.20.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.5 MB/s  0:00:00
# Downloading sagemaker_mlops-1.20.0-py3-none-any.whl (223 kB)
# Downloading sagemaker_serve-1.20.0-py3-none-any.whl (297 kB)
# Downloading sagemaker_train-1.20.0-py3-none-any.whl (446 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached mlflow-3.15.1-py3-none-any.whl (11.2 MB)
# Using cached mlflow_skinny-3.15.1-py3-none-any.whl (3.6 MB)
# Using cached mlflow_tracing-3.15.1-py3-none-any.whl (1.8 MB)
# Using cached aiohttp-3.14.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# Using cached alembic-1.19.1-py3-none-any.whl (265 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached cryptography-49.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
# Downloading databricks_sdk-0.133.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 90.5 MB/s  0:00:00
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached flask_cors-6.0.5-py3-none-any.whl (16 kB)
# Using cached gitpython-3.1.59-py3-none-any.whl (220 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.56.3-py3-none-any.whl (259 kB)
# Downloading gunicorn-26.1.0-py3-none-any.whl (216 kB)
# Using cached huey-3.3.4-py3-none-any.whl (123 kB)
# Using cached matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
# Using cached multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
# Using cached opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Using cached opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Using cached pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (50.1 MB)
# Downloading python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Using cached sagemaker_mlflow-0.5.0-py3-none-any.whl (31 kB)
# Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Using cached skops-0.14.0-py3-none-any.whl (132 kB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading sqlalchemy-2.0.52-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 194.8 MB/s  0:00:00
# Downloading sqlparse-0.6.0-py3-none-any.whl (50 kB)
# Using cached yarl-1.24.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (110 kB)
# Using cached aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cffi-2.1.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (218 kB)
# Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
# Using cached frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached paramiko-5.0.0-py3-none-any.whl (208 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
# Using cached invoke-3.0.3-py3-none-any.whl (160 kB)
# Using cached pillow-12.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
# Using cached propcache-0.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (60 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyiceberg-0.11.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (705 kB)
# Using cached cachetools-6.2.6-py3-none-any.whl (11 kB)
# Using cached mmh3-5.2.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (101 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached pyroaring-1.1.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
# Using cached strictyaml-1.7.3-py3-none-any.whl (123 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached zstandard-0.25.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
# Using cached pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached torch-2.13.0-cp310-cp310-manylinux_2_28_x86_64.whl (526.6 MB)
# Using cached cuda_toolkit-13.0.3.0-py2.py3-none-any.whl (2.5 kB)
# Using cached nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (366.2 MB)
# Using cached nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl (170.1 MB)
# Using cached nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl (206.0 MB)
# Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
# Using cached triton-3.7.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (197.6 MB)
# Using cached cuda_bindings-13.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.7 MB)
# Using cached nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)

# %% [markdown]
# ## 1. Extracting information from a webpage
# ([Go to top](#Lab-3.1:-Extracting-text-from-the-web))
#
# In this section, you will use Beautiful Soup to extract the titles, authors, summaries, published data, and hyperlinks from blog posts. The extracted text could then be used in a downstream NLP task, such as topic extraction, sentiment analysis, text-to-speech, or translation.

# %% [markdown]
# Start by importing both the **Beautiful Soup** and **requests** packages.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# The blog post you will parse is the [AWS Machine Learning blog](https://aws.amazon.com/blogs/machine-learning/) at https://aws.amazon.com/blogs/machine-learning/.
#
# Using your web browser, open the AWS Machine Learning page.
#
# Use the browser's *inspector mode* to discover the structure of the page. In Mozilla FireFox and Google Chrome, you can open the inspector by pressing CTRL+SHIFT+C. If you use a different browser, consult the browser documentation.
#
# View the different elements of the webpage by moving your pointer over the page. Move the pointer over the following elements, and see whether you can find the tags that are used to identify the informtion:
#
# * Title of the blog post
# * Author
# * Date published
# * Text summary
# * Hyperlink to the blog post
#
# Don't worry if you can't find all the tags. The following code walkthrough will help you find tags.

# %% [markdown]
# First, use the **requests** library to load the webpage. Before you proceed, confirm that the HTTP status code is *200*.

# %%
page = requests.get('https://aws.amazon.com/blogs/machine-learning/')
page.status_code

# %% [markdown]
# Load the **content** from the page into a **soup** object.

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# View the entire page by using the `soup.prettify()` function.
#
# **Note:** The content from the AWS Blogs page might be lengthy. To move to the next task, scroll down in this notebook.

# %%
print(soup.prettify())

# %% [markdown]
# All the elements on the page can be accessed using dot (.) notation. Thus, to view the title, you could use `soup.title`. If you want only the `text`, use the text element as follows:

# %%
print(soup.title.text)

# %% [markdown]
# When you used the inspector to search for tags on the AWS Blogs page, you might have found that blog-post content is organized/categorized/marked with `<article>` tags, which indicate a self-contained unit of content.

# %%
print(soup.article.prettify())

# %% [markdown]
# Review the output. Can you find the title?

# %% [markdown]
# The title can be found at `soup.article.h2.span`:

# %%
print(soup.article.h2.span.prettify())

# %% [markdown]
# To display only the text, use the `text` property:

# %%
print(soup.article.h2.span.text)

# %% [markdown]
# Find the publish date of the article:

# %%
print(soup.article.time.text)

# %% [markdown]
# Next, extract the article summary:

# %%
print(soup.article.section.p.text)

# %% [markdown]
# The author name is in the footer. A blog post can have multiple authors. However, for now, retrieve only the *first author*:

# %%
print(soup.article.footer.span.prettify())

# %% [markdown]
# The hyperlink to the full article text is the last piece of information that you must find:

# %%
print(soup.article.div.a['href'])

# %% [markdown]
# You have now identified all the relevant elements. You can find all the articles by using the `find_all()` function. You can then loop through the results and output information about the blog post, such as the title, author, and so on.
#
# For example, to find all the authors and then loop through them, the author, use `find_all()`:

# %%
for article in soup.find_all('article'):
    print('==========================================')
    print(article.h2.span.text)
    authors = article.footer.find_all('span', {"property":"author"})
    print('by', end=' ')
    for author in authors:
        if author.span != None:
            print(author.span.text, end=', ')
    print(f'on {article.time.text}')
    print(article.section.p.text)
    print(article.div.a['href'])

# %% [markdown]
# After you figure out the data format, you can add the results to an array:

# %%
blog_posts = []
for article in soup.find_all('article'):
    authors = article.footer.find_all('span', {"property":"author"})
    author_text = []
    for author in authors:
        if author.span != None:
            author_text.append(author.span.text)
    blog_posts.append([article.h2.span.text, ', '.join(author_text), article.time.text, article.section.p.text, article.div.a['href'] ])

# %% [markdown]
# Next, load the array into a pandas dataframe:

# %%
import pandas as pd
import time

# %%
df = pd.DataFrame(blog_posts, columns=['title','authors','published','summary','link'])

# %% [markdown]
# You must convert the **published** column to a `datetime` value.

# %%
df['published'] = pd.to_datetime(df['published'], format='%d %b %Y')

# %% [markdown]
# Adjust the column width for pandas, and display the first five rows of the dataframe:

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', None)
df.head()

# %% [markdown]
# Now that the data is in a pandas dataframe, you can use this data in downstream NLP tasks. You will come back to this data in Module 5.

# %% [markdown]
# ## 2. Extracting text from images
# ([Go to top](#Lab-3.1:-Extracting-text-from-the-web))
#
# In this section, you will extract the text from an image by using Amazon Textract.
#
# For this exercise, you will use the following simple image. This file was loaded into Amazon Simple Storage Service (Amazon S3) when you started the lab.
#
# ![Image of a simple document](../s3/simple-document-image.jpg)

# %% [markdown]
# Start by importing the library for the AWS SDK for Python (Boto3).

# %%
import boto3

# %% [markdown]
# Setup the variables for the bucket and document name.

# %%
# Document
s3BucketName = "c220108a5553130l16283487t1w650921235359-labbucket-p3vgcmedulwt"
documentName = "lab31/simple-document-image.jpg"

# %% [markdown]
# Extract text from the image by using Amazon Textract to call an application programming interface (API).

# %%
# Amazon Textract client
textract = boto3.client('textract')

# Call Amazon Textract
response = textract.detect_document_text(
    Document={
        'S3Object': {
            'Bucket': s3BucketName,
            'Name': documentName
        }
    })

print(response)

# %% [markdown]
# The response looks unformatted, but the **Blocks** list contains the key information that you need.
#
# Extract this information from the **Blocks** list:

# %%
# Print text
print("\nText\n========")
text = ""
for item in response["Blocks"]:
    if item["BlockType"] == "LINE":
        print ('\033[94m' +  item["Text"] + '\033[0m')
        text = text + " " + item["Text"]

# %% [markdown]
# You have now extracted the text from the image. You can use this text in a downstream NLP task.

# %% [markdown]
# You will now experiment with one additional image. This image contains *tables* of text.
#
# ![Image of Employment Application](../s3/employmentapp.png)

# %% [markdown]
# Set the new document name:

# %%
# Document
documentName = "lab31/employmentapp.png"

# %% [markdown]
# Call the Amazon Textract API again. However, this time, specify the **TABLES** feature type:

# %%
# Amazon Textract client

response = textract.analyze_document(
    Document={
        'S3Object': {
            'Bucket': s3BucketName,
            'Name': documentName
        }
    },
    FeatureTypes=["TABLES"])

# %% [markdown]
# Parse the table by using the Amazon Textract results parser (**textract-trp**).
#
# **Note:** You installed the Amazon Textract results parser when you ran the `pip install --upgrade textract-trp` command at the start of this notebook.

# %%
from trp import Document
doc = Document(response)

for page in doc.pages:
    for table in page.tables:
        for r, row in enumerate(table.rows):
            for c, cell in enumerate(row.cells):
                print("Table[{}][{}] = {}".format(r, c, cell.text))

# %% [markdown]
# You have now extracted the text from a different image, and you could continue to process it further, if needed.

# %% [markdown]
# # Congratulations!
#
# You have completed this lab, and you can now end the lab by following the lab guide instructions.

# %% [markdown]
# *©2023 Amazon Web Services, Inc. or its affiliates. All rights reserved. This work may not be reproduced or redistributed, in whole or in part, without prior written permission from Amazon Web Services, Inc. Commercial copying, lending, or selling is prohibited. All trademarks are the property of their owners.*
